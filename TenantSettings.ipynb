# %%
###################################################################################################
# Import required libraries
###################################################################################################
import requests
import adal
import json
import pandas as pd
from datetime import date

#location where export file will be saves- use File API path
path = '/lakehouse/default/Files/TenantSettings/'
activityDate = date.today().strftime("%Y-%m-%d")

###################################################################################################
# Authenticate for owner of notebook - Tenant settings API does not support service principal
###################################################################################################

pbi_access_token = mssparkutils.credentials.getToken("https://analysis.windows.net/powerbi/api")


############################################################################################################
# Call API with GET request to TenantSettingsURL (call endpoint and pass token as header for authentication)
############################################################################################################

TenantSettingsURL = 'https://api.fabric.microsoft.com/v1/admin/tenantsettings'
header = {'Authorization': f'Bearer {pbi_access_token}'}
TenantSettingsJSON = requests.get(TenantSettingsURL , headers=header)

#Parse the response as a JSON object and extract the tenantSettings key
TenantSettingsJSONContent = json.loads(TenantSettingsJSON.content)
TenantSettingsJSONContentExplode = TenantSettingsJSONContent.get('tenantSettings')

# Convert list of dictionaries into pandas dataframe 
df = pd.DataFrame(TenantSettingsJSONContentExplode)

# Add new column ExportedDate to df and save df as csv
df['ExportedDate'] = activityDate
df.to_csv(path + activityDate + '_TenantSettings.csv', index=False) 

# When running for the first time - use "overwrite" - change to "append" later
df = spark.read.format("csv").option("header","true").load("Files/TenantSettings/*.csv")
df.write.mode("overwrite").format("delta").saveAsTable("TenantSettings")
# Out:
# Collecting azure.identity
#   Obtaining dependency information for azure.identity from https://files.pythonhosted.org/packages/30/10/5dbf755b368d10a28d55b06ac1f12512a13e88874a23db82defdea9a8cd9/azure_identity-1.15.0-py3-none-any.whl.metadata
#   Downloading azure_identity-1.15.0-py3-none-any.whl.metadata (75 kB)
#      ---------------------------------------- 0.0/75.4 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/75.4 kB ? eta -:--:--
#      ---------- --------------------------- 20.5/75.4 kB 131.3 kB/s eta 0:00:01
#      ------------------------- ------------ 51.2/75.4 kB 327.7 kB/s eta 0:00:01
#      ------------------------------ ------- 61.4/75.4 kB 363.1 kB/s eta 0:00:01
#      -------------------------------------- 75.4/75.4 kB 348.7 kB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.23.0 (from azure.identity)
#   Obtaining dependency information for azure-core<2.0.0,>=1.23.0 from https://files.pythonhosted.org/packages/b0/e2/b6cdd23d8d9cc430410cc309879883aff67736c02528cd1fdc07c48158b1/azure_core-1.29.6-py3-none-any.whl.metadata
#   Downloading azure_core-1.29.6-py3-none-any.whl.metadata (36 kB)
# Collecting cryptography>=2.5 (from azure.identity)
#   Obtaining dependency information for cryptography>=2.5 from https://files.pythonhosted.org/packages/f6/23/b28f4a03650512efff13a8fcbb977bac178a765c5a887a6720bee13fa85b/cryptography-41.0.7-cp37-abi3-win_amd64.whl.metadata
#   Downloading cryptography-41.0.7-cp37-abi3-win_amd64.whl.metadata (5.3 kB)
# Collecting msal<2.0.0,>=1.24.0 (from azure.identity)
#   Obtaining dependency information for msal<2.0.0,>=1.24.0 from https://files.pythonhosted.org/packages/b7/61/2756b963e84db6946e4b93a8e288595106286fc11c7129fcb869267ead67/msal-1.26.0-py2.py3-none-any.whl.metadata
#   Downloading msal-1.26.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions<2.0.0,>=0.3.0 (from azure.identity)
#   Obtaining dependency information for msal-extensions<2.0.0,>=0.3.0 from https://files.pythonhosted.org/packages/78/8d/ecd0eb93196f25c722ba1b923fd54d190366feccfa5b159d48dacf2b1fee/msal_extensions-1.1.0-py3-none-any.whl.metadata
#   Downloading msal_extensions-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting anyio<5.0,>=3.0 (from azure-core<2.0.0,>=1.23.0->azure.identity)
#   Obtaining dependency information for anyio<5.0,>=3.0 from https://files.pythonhosted.org/packages/bf/cd/d6d9bb1dadf73e7af02d18225cbd2c93f8552e13130484f1c8dcfece292b/anyio-4.2.0-py3-none-any.whl.metadata
#   Downloading anyio-4.2.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\apappila\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-core<2.0.0,>=1.23.0->azure.identity) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\apappila\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-core<2.0.0,>=1.23.0->azure.identity) (1.16.0)
# Collecting typing-extensions>=4.6.0 (from azure-core<2.0.0,>=1.23.0->azure.identity)
#   Obtaining dependency information for typing-extensions>=4.6.0 from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting cffi>=1.12 (from cryptography>=2.5->azure.identity)
#   Obtaining dependency information for cffi>=1.12 from https://files.pythonhosted.org/packages/5a/c7/694814b3757878b29da39bc2f0cf9d20295f4c1e0a0bde7971708d5f23f8/cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata (1.5 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0 (from msal<2.0.0,>=1.24.0->azure.identity)
#   Obtaining dependency information for PyJWT[crypto]<3,>=1.0.0 from https://files.pythonhosted.org/packages/2b/4f/e04a8067c7c96c364cef7ef73906504e2f40d690811c021e1a1901473a19/PyJWT-2.8.0-py3-none-any.whl.metadata
#   Downloading PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: packaging in c:\users\apappila\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from msal-extensions<2.0.0,>=0.3.0->azure.identity) (23.2)
# Collecting portalocker<3,>=1.6 (from msal-extensions<2.0.0,>=0.3.0->azure.identity)
#   Obtaining dependency information for portalocker<3,>=1.6 from https://files.pythonhosted.org/packages/17/9e/87671efcca80ba6203811540ed1f9c0462c1609d2281d7b7f53cef05da3d/portalocker-2.8.2-py3-none-any.whl.metadata
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\apappila\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.23.0->azure.identity) (3.6)
# Collecting sniffio>=1.1 (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.23.0->azure.identity)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=2.5->azure.identity)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\apappila\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from portalocker<3,>=1.6->msal-extensions<2.0.0,>=0.3.0->azure.identity) (306)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\apappila\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure.identity) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\apappila\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure.identity) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\apappila\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure.identity) (2023.11.17)
# Downloading azure_identity-1.15.0-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.7 kB ? eta -:--:--
#    ---------------------------------------- 164.7/164.7 kB 9.7 MB/s eta 0:00:00
# Downloading azure_core-1.29.6-py3-none-any.whl (192 kB)
#    ---------------------------------------- 0.0/192.5 kB ? eta -:--:--
#    ------------------------------------ --- 174.1/192.5 kB ? eta -:--:--
#    ---------------------------------------- 192.5/192.5 kB 3.9 MB/s eta 0:00:00
# Downloading cryptography-41.0.7-cp37-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------- ------------------------------ 0.7/2.7 MB 13.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.7/2.7 MB 7.6 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.7 MB 10.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.5/2.7 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.7 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.7 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 8.1 MB/s eta 0:00:00
# Downloading msal-1.26.0-py2.py3-none-any.whl (99 kB)
#    ---------------------------------------- 0.0/99.0 kB ? eta -:--:--
#    ---------------------------------------- 99.0/99.0 kB ? eta 0:00:00
# Downloading msal_extensions-1.1.0-py3-none-any.whl (19 kB)
# Downloading anyio-4.2.0-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.5 kB ? eta -:--:--
#    ---------------------------------------- 85.5/85.5 kB 5.0 MB/s eta 0:00:00
# Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.5 kB ? eta -:--:--
#    -------------------- ------------------- 92.2/181.5 kB ? eta -:--:--
#    ---------------------------------------- 181.5/181.5 kB 2.8 MB/s eta 0:00:00
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Installing collected packages: typing-extensions, sniffio, PyJWT, pycparser, portalocker, cffi, anyio, cryptography, azure-core, msal, msal-extensions, azure.identity
# Successfully installed PyJWT-2.8.0 anyio-4.2.0 azure-core-1.29.6 azure.identity-1.15.0 cffi-1.16.0 cryptography-41.0.7 msal-1.26.0 msal-extensions-1.1.0 portalocker-2.8.2 pycparser-2.21 sniffio-1.3.0 typing-extensions-4.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\apappila\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 15
#      10      from azure.identity import ClientSecretCredential
#      13 ########################################################################################
#      14 #Define variables used for creation of embed token
# ---> 15 print(tenant)
#      16 api = 'https://analysis.windows.net/powerbi/api/.default'
#      17 print(client_id)
#
# NameError: name 'tenant' is not defined
